# %% [markdown]
# <a href="https://colab.research.google.com/github/SirDripset/Disease_Mapping/blob/main/updated_disease_mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_csv('asthma_disease_gda_summary.csv')
df1 = df1.drop(columns=['Disease_id','First_Ref','Last_Ref'])
df1
# Out:
#      Disease     Gene  Gene_id UniProt  \
# 0     Asthma    TBX21    30009  Q9UL17
# 1     Asthma      IL5     3567  P05113
# 2     Asthma     IL13     3596  P35225
# 3     Asthma    CCL11     6356  P51671
# 4     Asthma    TGFB1     7040  P01137
# ...      ...      ...      ...     ...
# 2091  Asthma    ESPL1     9700  Q14674
# 2092  Asthma    KNTC1     9735  P50748
# 2093  Asthma  GPRASP1     9737  Q5JY77
# 2094  Asthma    CD151      977  P48509
# 2095  Asthma    KEAP1     9817  Q14145
#
#                                          Gene_Full_Name         Protein_Class  \
# 0                         T-box transcription factor 21  Transcription factor
# 1                                         interleukin 5                   NaN
# 2                                        interleukin 13                   NaN
# 3                         C-C motif chemokine ligand 11             Signaling
# 4                     transforming growth factor beta 1             Signaling
# ...

# %%
df2 = pd.read_csv('obesity_disease_gda_summary.csv')
df2 = df2.drop(columns=['Disease_id','First_Ref','Last_Ref'])
df2
# Out:
#       Disease     Gene  Gene_id UniProt  \
# 0     Obesity     MC4R     4160  P32245
# 1     Obesity    PPARG     5468  P37231
# 2     Obesity     POMC     5443  P01189
# 3     Obesity      CPE     1363  P16870
# 4     Obesity     AGRP      181  O00253
# ...       ...      ...      ...     ...
# 2816  Obesity  KBTBD11     9920  O94819
# 2817  Obesity   LPGAT1     9926  Q92604
# 2818  Obesity   THRAP3     9967  Q9Y2W1
# 2819  Obesity    CDC42      998  P60953
# 2820  Obesity    KCNE2     9992  Q9Y6J6
#
#                                          Gene_Full_Name  \
# 0                               melanocortin 4 receptor
# 1      peroxisome proliferator activated receptor gamma
# 2                                   proopiomelanocortin
# 3                                    carboxypeptidase E
# 4                           agouti related neuropeptide
# ...                                                 ...
# 2816          kelch repeat and BTB domain containing 11
# ...

# %%
df3 = pd.read_csv('finngen_R7_ASTHMA_OBESITY_lead.tsv', sep='\t')
df3 = df3.drop(columns=['rsids','UKBB'])
df3
# Out:
#      chrom        pos   ref alt nearest_genes      most_severe      info  \
# 0       16   53765595     G   A           FTO           intron  0.998334
# 1        6   32454571     C   T       HLA-DRA       intergenic  0.999401
# 2       20   59231047     A   G        ZNF831           intron  0.992428
# 3        6   31560353     C   T       NFKBIL1  downstream gene  0.999966
# 4        7   12014171     T  TA        THSD7A       intergenic  0.984077
# ..     ...        ...   ...  ..           ...              ...       ...
# 296      9   18232038     C   T      ADAMTSL1           intron  0.985035
# 297      6   39391230     C   A          KIF6           intron  0.848789
# 298     14   99624206  TCTC   T       CCDC85C           intron  0.986912
# 299      3  149658902     G   A         WWTR1           intron  0.872373
# 300      6   55004812     A  AT        FAM83B       intergenic  0.606948
#
#      fin_enrichment       maf  maf_cases  maf_controls      beta  \
# ...

# %%
df1['Gene'].value_counts()
# Out:
# ELAVL2      1
# ADORA1      1
# PLAUR       1
# PTAFR       1
# HSP90AB1    1
#            ..
# MRGPRX4     1
# SOCS3       1
# PDCD4       1
# CPSF4       1
# PTGER2      1
# Name: Gene, Length: 2096, dtype: int64

# %%
df2['Gene'].value_counts()
# Out:
# PPIF        1
# UCP3        1
# SLC16A1     1
# GNPDA2      1
# CAST        1
#            ..
# SOCS3       1
# CRX         1
# HDAC3       1
# PPP1R14A    1
# GPR12       1
# Name: Gene, Length: 2821, dtype: int64

# %%
df3['nearest_genes'].value_counts()
# Out:
# ADGRL3    3
# CA10      2
# PCDH7     2
# MGAT4C    2
# AMY1C     2
#          ..
# PSAT1     1
# EFHB      1
# LARS2     1
# KCNK3     1
# OR5H15    1
# Name: nearest_genes, Length: 292, dtype: int64

# %%
disgen_df = df2['Gene'].to_list()
output = []
for Gene in df1['Gene']:
    if Gene in disgen_df:
        output.append(Gene)

# %%
print(output)
# Out:
# ['IL5', 'IL13', 'CCL11', 'TGFB1', 'ICAM1', 'IL4', 'IL6', 'MMP9', 'NOS2', 'CCL2', 'CCL5', 'ADRB2', 'ALOX5', 'HLA-DQB1', 'HLA-DRB1', 'TNF', 'TSLP', 'IL33', 'IL6R', 'PDE4D', 'PLA2G7', 'PARP1', 'EDN1', 'GSTM1', 'GSTP1', 'TNC', 'IL1B', 'IL1RN', 'ARG1', 'VEGFA', 'CAT', 'CD14', 'ARG2', 'NQO1', 'MMP1', 'ALDH2', 'SOD1', 'BCL2', 'HMOX1', 'PLAU', 'IFNL3', 'NPY', 'PTEN', 'BGLAP', 'TIMP3', 'DNMT1', 'EGFR', 'NR3C1', 'HSD11B2', 'IL10', 'IL17A', 'SERPINE1', 'IL22', 'PDE4B', 'SERPINA1', 'PTGS2', 'CCL17', 'CXCL14', 'AGER', 'SFTPD', 'STAT4', 'CCL22', 'C5AR1', 'TLR3', 'PIN1', 'C3AR1', 'CD40', 'ESR2', 'FAS', 'PLA2G4A', 'VIP', 'EDNRB', 'RHOA', 'MIF', 'SFTPA1', 'UTS2', 'AGTR1', 'AGTR2', 'PDGFB', 'SFTPB', 'UCN', 'CFTR', 'DCN', 'ITGB6', 'PIK3CD', 'BDKRB2', 'SLC22A1', 'STAT3', 'NOD2', 'TNFSF4', 'TLR10', 'SMAD3', 'ATG5', 'ADA', 'IL1R1', 'IL2RB', 'ADORA1', 'IRF4', 'ITGAX', 'COL1A1', 'ERBB2', 'MTOR', 'DLL1', 'ITLN1', 'CASP8', 'FADS2', 'NEDD4L', 'PTPN22', 'GLI2', 'HLA-B', 'KLK3', 'ITPR3', 'KRT7', 'FADS1', 'PLEK',
# ...

# %%
asthma_matched = df1.loc[df1['Gene'].isin(['IL5', 'IL13', 'CCL11', 'TGFB1', 'ICAM1', 'IL4', 'IL6', 'MMP9', 'NOS2', 'CCL2', 'CCL5', 'ADRB2', 'ALOX5', 'HLA-DQB1', 'HLA-DRB1', 'TNF', 'TSLP', 'IL33', 'IL6R', 'PDE4D', 'PLA2G7', 'PARP1', 'EDN1', 'GSTM1', 'GSTP1', 'TNC', 'IL1B', 'IL1RN', 'ARG1', 'VEGFA', 'CAT', 'CD14', 'ARG2', 'NQO1', 'MMP1', 'ALDH2', 'SOD1', 'BCL2', 'HMOX1', 'PLAU', 'IFNL3', 'NPY', 'PTEN', 'BGLAP', 'TIMP3', 'DNMT1', 'EGFR', 'NR3C1', 'HSD11B2', 'IL10', 'IL17A', 'SERPINE1', 'IL22', 'PDE4B', 'SERPINA1', 'PTGS2', 'CCL17', 'CXCL14', 'AGER', 'SFTPD', 'STAT4', 'CCL22', 'C5AR1', 'TLR3', 'PIN1', 'C3AR1', 'CD40', 'ESR2', 'FAS', 'PLA2G4A', 'VIP', 'EDNRB', 'RHOA', 'MIF', 'SFTPA1', 'UTS2', 'AGTR1', 'AGTR2', 'PDGFB', 'SFTPB', 'UCN', 'CFTR', 'DCN', 'ITGB6', 'PIK3CD', 'BDKRB2', 'SLC22A1', 'STAT3', 'NOD2', 'TNFSF4', 'TLR10', 'SMAD3', 'ATG5', 'ADA', 'IL1R1', 'IL2RB', 'ADORA1', 'IRF4', 'ITGAX', 'COL1A1', 'ERBB2', 'MTOR', 'DLL1', 'ITLN1', 'CASP8', 'FADS2', 'NEDD4L', 'PTPN22', 'GLI2', 'HLA-B', 'KLK3', 'ITPR3', 'KRT7', 'FADS1', 'PLEK', 'CCHCR1', 'PROC', 'PTCH1', 'PTPRC', 'SLC6A12', 'TBX1', 'RUNX1', 'PTGES', 'CEL', 'AHSA1', 'POSTN', 'MTCO2P12', 'CETP', 'SLC27A5', 'CHI3L1', 'CHRNA2', 'NLRP3', 'CCR5', 'CCR6', 'RBM45', 'COMT', 'SLCO6A1', 'CRK', 'CRP', 'MAPK14', 'CSF2', 'CTLA4', 'CTNNB1', 'ACE', 'SLC30A8', 'EDNRA', 'AHR', 'ERBB4', 'ERCC2', 'F2RL1', 'TMEM26', 'JMJD1C', 'FGF8', 'FGFR1', 'ZNF365', 'SIK2', 'SIK3', 'ZFPM2', 'CRB1', 'ALOX5AP', 'GABPA', 'RNF19A', 'COPD', 'POLDIP2', 'HAVCR1', 'IL37', 'GLB1', 'HPGDS', 'GLDC', 'GNAS', 'GP1BB', 'GSTT1', 'HDAC2', 'HLA-DRB3', 'HMGB1', 'IFNA1', 'IFNA13', 'IFNB1', 'MCIDAS', 'IFNG', 'IL1A', 'IL2', 'CXCL8', 'IL9', 'IL18', 'CXCL10', 'GSTK1', 'KNG1', 'LEP', 'CASC15', 'LTA', 'MIR146A', 'MIR155', 'MBL2', 'ARVCF', 'PLF', 'COX2', 'RERE', 'NFE2L2', 'NGF', 'NOS1', 'NOS3', 'ORM1', 'PDE11A', 'FOXP3', 'WDPCP', 'SUFU', 'PIK3CA', 'PIK3CB', 'PIK3CG', 'CDKAL1', 'ATG16L1', 'PRKG1', 'MAPK1', 'MYDGF', 'ACKR3', 'PTGDR', 'PTGDS', 'PTPN2', 'BBS1', 'RPGR', 'RREB1', 'BDNF', 'ATXN2', 'IL25', 'BRCA2', 'STAT5B', 'BRS3', 'TAC1', 'TBXA2R', 'TFRC', 'TLR2', 'TLR4', 'HIRA', 'UFD1', 'VDR', 'TRPV1', 'ZBTB16', 'ALMS1', 'CCDC28B', 'AIMP2', 'TBL1XR1', 'SPSB1', 'ARHGAP24', 'PARP9', 'ATRN', 'OFD1', 'SLC16A7', 'ADIPOQ', 'GRAP2', 'MAP4K4', 'SEC24C', 'LPIN2', 'CXCR6', 'CHIT1', 'ADRA1A', 'ADRA2B', 'GPR42', 'IL15', 'MPO', 'PLG', 'SSTR4', 'LPAR2', 'AKT1', 'GC', 'HIF1A', 'PPARG', 'PTGS1', 'VCAM1', 'NR1I2', 'WDHD1', 'OXER1', 'FCGR3A', 'CXCR3', 'IL16', 'MIR21', 'MMP12', 'IL23A', 'ACTB', 'CCL20', 'STAT1', 'CAMP', 'SOCS3', 'CD38', 'CCN2', 'DPP4', 'AGT', 'EPHB2', 'ESR1', 'AKR1B1', 'FN1', 'FOS', 'IL27', 'HSPA4', 'MIR221', 'MRC1', 'MUC1', 'RNASE2', 'CXCL12', 'SMPD1', 'TIMP1', 'CCR2', 'CCL27', 'FCGR3B', 'FKBP5', 'MMRN1', 'ALOX15', 'NRG1', 'IRF1', 'LGALS3', 'SMAD2', 'KITLG', 'MAPK8', 'IL21', 'S100A8', 'SOD2', 'SPP1', 'C3', 'CD1D', 'IL32', 'TNFSF13B', 'IRAK3', 'ADCY9', 'MRGPRX3', 'MRGPRX4', 'CMA1', 'GPR151', 'CREB1', 'CSF3', 'CX3CR1', 'CYP24A1', 'CYP27B1', 'DEFB1', 'DUSP1', 'EGR1', 'ELANE', 'F3', 'GPRC6A', 'FGF2', 'SIRT1', 'LPAR3', 'MRGPRX1', 'GCG', 'IFNL1', 'H19', 'LEPR', 'MIR126', 'MIR145', 'MAS1', 'VN1R17P', 'GPR166P', 'MTHFR', 'MYD88', 'ATP5F1A', 'PLA2G2A', 'POMC', 'SAGE1', 'MAPK3', 'TRPV4', 'LGR6', 'SCD', 'CCL18', 'CX3CL1', 'ST2', 'POTEF', 'TNFRSF4', 'TRPM8', 'FZD4', 'CASP1', 'MBD2', 'ENTPD1', 'FAM13A', 'FSTL1', 'GSTO2', 'CCR7', 'COX8A', 'CYBA', 'DECR1', 'EGF', 'FCGR2B', 'FDXR', 'FKBP4', 'ATF6', 'FLNC', 'GAPDH', 'GGT1', 'ABO', 'ANGPT1', 'HP', 'APOA1', 'IGF1', 'IGF1R', 'APRT', 'IRF5', 'ITGAM', 'JAK3', 'LIF', 'MIR152', 'ARSA', 'MFAP1', 'MMP2', 'NEUROD1', 'NFKB1', 'NM', 'P2RX7', 'SERPINB2', 'ACP1', 'TREM1', 'PON1', 'PRKCA', 'KIDINS220', 'PTPN11', 'RAC1', 'MOK', 'CCND1', 'RGS2', 'S100A9', 'CCL19', 'SELE', 'SOAT1', 'THBS1', 'TSPO', 'TRAF6', 'YY1', 'CXCR4', 'CALCA', 'BECN1', 'CD48', 'CD68', 'CD69', 'CDC42', 'HDAC6', 'LINC01672', 'PGR-AS1', 'LRPPRC', 'CDKN1B', 'SEMA3A', 'KAT5', 'PRRT2', 'CHRM2', 'CHRNA3', 'CLU', 'GNPDA2', 'ADM', 'PPARGC1B', 'ADORA2A', 'CREBBP', 'CRHR2', 'CTSS', 'CYBB', 'CYP1A2', 'CYP2B6', 'ABCA1', 'F2R', 'PTK2B', 'FGF1', 'FOXM1', 'FOXO1', 'FOXO3', 'FPR2', 'ALPL', 'GJA1', 'ACAD8', 'RGMB', 'FLVCR1', 'ANPEP', 'CD274', 'CXCL1', 'ANXA1', 'ANXA2', 'FOXA2', 'HSPA1B', 'HSP90AA1', 'APOE', 'IGFBP3', 'APP', 'IL6ST', 'TNFRSF9', 'IDO1', 'INSRR', 'IRF7', 'ARNTL', 'MIR192', 'MIR200A', 'MIR216A', 'MIR22', 'MEFV', 'ACHE', 'CD200', 'MUSK', 'MYC', 'NHS', 'TNFRSF11B', 'OSM', 'NOX4', 'TAS2R14', 'PCNA', 'TLR8', 'PDCD1', 'PECAM1', 'PLD1', 'PMCH', 'PNOC', 'PPARA', 'PRKCB', 'EAF2', 'PSMB6', 'PTPN6', 'PTPRE', 'RAPSN', 'ACE2', 'RBP4', 'RGS4', 'BCL6', 'ROS1', 'RPE65', 'CCL3', 'CXCL11', 'SELP', 'SEMA4A', 'CLEC7A', 'SLC6A4', 'GGTLC5P', 'SLC8A1', 'SNRNP70', 'TAC3', 'TEK', 'TFF2', 'TGFBR2', 'THBD', 'TM7SF2', 'TP53', 'TRPC3', 'GGTLC3', 'GGT2', 'TWIST1', 'GGTLC4P', 'TYRO3', 'XBP1', 'FTO', 'NR4A3', 'FLAD1', 'TAGLN2', 'NR0B2', 'IL1F10', 'SOCS1', 'TNFSF10', 'MSC', 'CD163', 'CLOCK', 'CD44', 'SEMA3E', 'HDAC4', 'ZGLP1', 'AAA1', 'DNM1L', 'CDH13', 'WASF2', 'CDKN1A', 'LOC102724197', 'YAP1', 'FST', 'CEACAM5', 'SEMA4D', 'SORBS1', 'KHDRBS1', 'CETN1', 'EBP', 'NES', 'CCR9', 'WASF3', 'PPARGC1A', 'SLC27A4', 'CHEK1', 'IL1RAPL1', 'AKAP13', 'CHRNA5', 'TXNRD3', 'CISH', 'CLN3', 'ADH1B', 'CNGB1', 'COL6A1', 'TMEM18', 'COL9A3', 'COMP', 'CORT', 'CPB2', 'CRH', 'HT', 'CSF1R', 'CST3', 'CSTA', 'PM20D1', 'CTSK', 'CYP1A1', 'CYP1B1', 'GRK2', 'CYP2E1', 'CYP3A4', 'CYP11A1', 'CYP27A1', 'DAG1', 'DGKG', 'DDIT3', 'DMD', 'ATN1', 'TSC22D3', 'AHSG', 'MLKL', 'EIF4E', 'ELAVL2', 'A2M', 'ELN', 'CRYBG1', 'AKT2', 'ESRRB', 'F10', 'F13A1', 'FABP4', 'THSD7A', 'FGF13', 'SIRT2', 'FAIM2', 'FLT1', 'DICER1', 'NUP62', 'LY96', 'NR5A1', 'FYN', 'G6PD', 'NEGR1', 'SPDEF', 'SH2B1', 'GAS6', 'GATA2', 'SLC17A5', 'AMH', 'GHRH', 'FOXP1', 'PDCD4', 'SGSM3', 'GLP1R', 'MAT2B', 'CAVIN1', 'GPR35', 'FFAR3', 'FFAR2', 'GRK5', 'GPX1', 'GPX3', 'GRN', 'PYCARD', 'TBK1', 'CXCL2', 'GRP', 'GSR', 'GTF2H1', 'HAS2', 'ANXA6', 'NR4A1', 'HOXD13', 'HES1', 'BIRC2', 'HSF1', 'BIRC3', 'HSPA1A', 'HSPA5', 'HSPB1', 'HSPD1', 'IGFBP1', 'IRF3', 'AR', 'ITGB2', 'MALAT1', 'THEMIS', 'LBP', 'LCT', 'LDLR', 'LGALS1', 'LIPA', 'LNPEP', 'LOX', 'LPA', 'LRP1', 'CYP4F3', 'MIR125A', 'MIR132', 'MIR140', 'MIR143', 'MIR149', 'MIR17', 'MIR19B1', 'MIR203A', 'MIR210', 'MIR223', 'MIR23A', 'MIR23B', 'MIR31', 'MIR34A', 'NBR1', 'ARRB2', 'STS', 'MBP', 'MC4R', 'MMP19', 'MTTP', 'ATF3', 'ATF4', 'ATM', 'NPPA', 'ATP2A2', 'ATP2A3', 'NTS', 'MIR378A', 'OGG1', 'OXTR', 'ATP5F1B', 'INSIG2', 'SLC45A2', 'DCTN4', 'TNFRSF12A', 'DACT1', 'SCLY', 'SIRT7', 'SIRT6', 'ENPP1', 'GHRL', 'ADA2', 'PGF', 'PGR', 'ABCB1', 'PIK3R1', 'PLA2G1B', 'SLC38A2', 'PON2', 'KRT20', 'UGT1A6', 'UGT1A1', 'UGT1A3', 'PPIA', 'MARCHF1', 'AVP', 'IMPACT', 'MEG3', 'MIR448', 'ADCY10', 'SELENOS', 'APOBR', 'MAPK9', 'MAP2K3', 'EIF2AK2', 'PRNP', 'CTNNBL1', 'CCL28', 'MIR20B', 'PTH', 'SLC24A3', 'MIR146B', 'PTX3', 'CXCL16', 'RARRES2', 'GER', 'REN', 'RFC2', 'RHO', 'BRD2', 'GAS5', 'ROBO1', 'MIR483', 'RYR2', 'S100A4', 'S100A12', 'S100B', 'SAA1', 'SAA2', 'SAT1', 'SCN10A', 'CCL7', 'CCL8', 'BID', 'CXCL5', 'BLK', 'SFRP4', 'SFRP5', 'HHIP', 'SHBG', 'ATPAF1', 'ST6GAL1', 'P2RY12', 'WNK1', 'SLC2A1', 'SLC22A2', 'BMPR2', 'SLPI', 'BNIP3', 'SOD3', 'SPARC', 'ST13', 'STAT5A', 'STC1', 'STK11', 'ADAM17', 'TADA2A', 'TAL1', 'BTF3P11', 'TAZ', 'TBL1X', 'HNF1A', 'MIR33B', 'TH', 'THBS2', 'TLR5', 'TNFRSF1A', 'TNNI3', 'TRPC1', 'TUFM', 'TYRP1', 'USF1', 'VLDLR', 'BEST1', 'WNT1', 'WNT7A', 'WNT10B', 'XDH', 'XRCC1', 'ZFP36', 'EHMT1', 'CALCR', 'DOCK5', 'WDR26', 'PNPLA3', 'ADAM12', 'SLC38A1', 'TAM', 'ITCH', 'PLA2G6', 'DGKE', 'CAV1', 'TNFSF14', 'NRP1', 'CCN4', 'SQSTM1', 'WASF1', 'CCNE1', 'CCT', 'SLC33A1', 'GGTLC1', 'AURKB', 'XPR1', 'MS4A1', 'KLF4', 'PPIG', 'GSTO1', 'CD33', 'LY86', 'CD36', 'SCARB2', 'TBPL1', 'KEAP1'])]
asthma_matched
# Out:
#      Disease    Gene  Gene_id UniProt                       Gene_Full_Name  \
# 1     Asthma     IL5     3567  P05113                        interleukin 5
# 2     Asthma    IL13     3596  P35225                       interleukin 13
# 3     Asthma   CCL11     6356  P51671        C-C motif chemokine ligand 11
# 4     Asthma   TGFB1     7040  P01137    transforming growth factor beta 1
# 5     Asthma   ICAM1     3383  P05362    intercellular adhesion molecule 1
# ...      ...     ...      ...     ...                                  ...
# 2078  Asthma    LY86     9450  O95711                lymphocyte antigen 86
# 2081  Asthma    CD36      948  P16671                        CD36 molecule
# 2082  Asthma  SCARB2      950  Q14108  scavenger receptor class B member 2
# 2083  Asthma   TBPL1     9519  P62380      TATA-box binding protein like 1
# 2095  Asthma   KEAP1     9817  Q14145  kelch like ECH associated protein 1
#
# ...

# %%
obesity_matched = df2.loc[df2['Gene'].isin(['IL5', 'IL13', 'CCL11', 'TGFB1', 'ICAM1', 'IL4', 'IL6', 'MMP9', 'NOS2', 'CCL2', 'CCL5', 'ADRB2', 'ALOX5', 'HLA-DQB1', 'HLA-DRB1', 'TNF', 'TSLP', 'IL33', 'IL6R', 'PDE4D', 'PLA2G7', 'PARP1', 'EDN1', 'GSTM1', 'GSTP1', 'TNC', 'IL1B', 'IL1RN', 'ARG1', 'VEGFA', 'CAT', 'CD14', 'ARG2', 'NQO1', 'MMP1', 'ALDH2', 'SOD1', 'BCL2', 'HMOX1', 'PLAU', 'IFNL3', 'NPY', 'PTEN', 'BGLAP', 'TIMP3', 'DNMT1', 'EGFR', 'NR3C1', 'HSD11B2', 'IL10', 'IL17A', 'SERPINE1', 'IL22', 'PDE4B', 'SERPINA1', 'PTGS2', 'CCL17', 'CXCL14', 'AGER', 'SFTPD', 'STAT4', 'CCL22', 'C5AR1', 'TLR3', 'PIN1', 'C3AR1', 'CD40', 'ESR2', 'FAS', 'PLA2G4A', 'VIP', 'EDNRB', 'RHOA', 'MIF', 'SFTPA1', 'UTS2', 'AGTR1', 'AGTR2', 'PDGFB', 'SFTPB', 'UCN', 'CFTR', 'DCN', 'ITGB6', 'PIK3CD', 'BDKRB2', 'SLC22A1', 'STAT3', 'NOD2', 'TNFSF4', 'TLR10', 'SMAD3', 'ATG5', 'ADA', 'IL1R1', 'IL2RB', 'ADORA1', 'IRF4', 'ITGAX', 'COL1A1', 'ERBB2', 'MTOR', 'DLL1', 'ITLN1', 'CASP8', 'FADS2', 'NEDD4L', 'PTPN22', 'GLI2', 'HLA-B', 'KLK3', 'ITPR3', 'KRT7', 'FADS1', 'PLEK', 'CCHCR1', 'PROC', 'PTCH1', 'PTPRC', 'SLC6A12', 'TBX1', 'RUNX1', 'PTGES', 'CEL', 'AHSA1', 'POSTN', 'MTCO2P12', 'CETP', 'SLC27A5', 'CHI3L1', 'CHRNA2', 'NLRP3', 'CCR5', 'CCR6', 'RBM45', 'COMT', 'SLCO6A1', 'CRK', 'CRP', 'MAPK14', 'CSF2', 'CTLA4', 'CTNNB1', 'ACE', 'SLC30A8', 'EDNRA', 'AHR', 'ERBB4', 'ERCC2', 'F2RL1', 'TMEM26', 'JMJD1C', 'FGF8', 'FGFR1', 'ZNF365', 'SIK2', 'SIK3', 'ZFPM2', 'CRB1', 'ALOX5AP', 'GABPA', 'RNF19A', 'COPD', 'POLDIP2', 'HAVCR1', 'IL37', 'GLB1', 'HPGDS', 'GLDC', 'GNAS', 'GP1BB', 'GSTT1', 'HDAC2', 'HLA-DRB3', 'HMGB1', 'IFNA1', 'IFNA13', 'IFNB1', 'MCIDAS', 'IFNG', 'IL1A', 'IL2', 'CXCL8', 'IL9', 'IL18', 'CXCL10', 'GSTK1', 'KNG1', 'LEP', 'CASC15', 'LTA', 'MIR146A', 'MIR155', 'MBL2', 'ARVCF', 'PLF', 'COX2', 'RERE', 'NFE2L2', 'NGF', 'NOS1', 'NOS3', 'ORM1', 'PDE11A', 'FOXP3', 'WDPCP', 'SUFU', 'PIK3CA', 'PIK3CB', 'PIK3CG', 'CDKAL1', 'ATG16L1', 'PRKG1', 'MAPK1', 'MYDGF', 'ACKR3', 'PTGDR', 'PTGDS', 'PTPN2', 'BBS1', 'RPGR', 'RREB1', 'BDNF', 'ATXN2', 'IL25', 'BRCA2', 'STAT5B', 'BRS3', 'TAC1', 'TBXA2R', 'TFRC', 'TLR2', 'TLR4', 'HIRA', 'UFD1', 'VDR', 'TRPV1', 'ZBTB16', 'ALMS1', 'CCDC28B', 'AIMP2', 'TBL1XR1', 'SPSB1', 'ARHGAP24', 'PARP9', 'ATRN', 'OFD1', 'SLC16A7', 'ADIPOQ', 'GRAP2', 'MAP4K4', 'SEC24C', 'LPIN2', 'CXCR6', 'CHIT1', 'ADRA1A', 'ADRA2B', 'GPR42', 'IL15', 'MPO', 'PLG', 'SSTR4', 'LPAR2', 'AKT1', 'GC', 'HIF1A', 'PPARG', 'PTGS1', 'VCAM1', 'NR1I2', 'WDHD1', 'OXER1', 'FCGR3A', 'CXCR3', 'IL16', 'MIR21', 'MMP12', 'IL23A', 'ACTB', 'CCL20', 'STAT1', 'CAMP', 'SOCS3', 'CD38', 'CCN2', 'DPP4', 'AGT', 'EPHB2', 'ESR1', 'AKR1B1', 'FN1', 'FOS', 'IL27', 'HSPA4', 'MIR221', 'MRC1', 'MUC1', 'RNASE2', 'CXCL12', 'SMPD1', 'TIMP1', 'CCR2', 'CCL27', 'FCGR3B', 'FKBP5', 'MMRN1', 'ALOX15', 'NRG1', 'IRF1', 'LGALS3', 'SMAD2', 'KITLG', 'MAPK8', 'IL21', 'S100A8', 'SOD2', 'SPP1', 'C3', 'CD1D', 'IL32', 'TNFSF13B', 'IRAK3', 'ADCY9', 'MRGPRX3', 'MRGPRX4', 'CMA1', 'GPR151', 'CREB1', 'CSF3', 'CX3CR1', 'CYP24A1', 'CYP27B1', 'DEFB1', 'DUSP1', 'EGR1', 'ELANE', 'F3', 'GPRC6A', 'FGF2', 'SIRT1', 'LPAR3', 'MRGPRX1', 'GCG', 'IFNL1', 'H19', 'LEPR', 'MIR126', 'MIR145', 'MAS1', 'VN1R17P', 'GPR166P', 'MTHFR', 'MYD88', 'ATP5F1A', 'PLA2G2A', 'POMC', 'SAGE1', 'MAPK3', 'TRPV4', 'LGR6', 'SCD', 'CCL18', 'CX3CL1', 'ST2', 'POTEF', 'TNFRSF4', 'TRPM8', 'FZD4', 'CASP1', 'MBD2', 'ENTPD1', 'FAM13A', 'FSTL1', 'GSTO2', 'CCR7', 'COX8A', 'CYBA', 'DECR1', 'EGF', 'FCGR2B', 'FDXR', 'FKBP4', 'ATF6', 'FLNC', 'GAPDH', 'GGT1', 'ABO', 'ANGPT1', 'HP', 'APOA1', 'IGF1', 'IGF1R', 'APRT', 'IRF5', 'ITGAM', 'JAK3', 'LIF', 'MIR152', 'ARSA', 'MFAP1', 'MMP2', 'NEUROD1', 'NFKB1', 'NM', 'P2RX7', 'SERPINB2', 'ACP1', 'TREM1', 'PON1', 'PRKCA', 'KIDINS220', 'PTPN11', 'RAC1', 'MOK', 'CCND1', 'RGS2', 'S100A9', 'CCL19', 'SELE', 'SOAT1', 'THBS1', 'TSPO', 'TRAF6', 'YY1', 'CXCR4', 'CALCA', 'BECN1', 'CD48', 'CD68', 'CD69', 'CDC42', 'HDAC6', 'LINC01672', 'PGR-AS1', 'LRPPRC', 'CDKN1B', 'SEMA3A', 'KAT5', 'PRRT2', 'CHRM2', 'CHRNA3', 'CLU', 'GNPDA2', 'ADM', 'PPARGC1B', 'ADORA2A', 'CREBBP', 'CRHR2', 'CTSS', 'CYBB', 'CYP1A2', 'CYP2B6', 'ABCA1', 'F2R', 'PTK2B', 'FGF1', 'FOXM1', 'FOXO1', 'FOXO3', 'FPR2', 'ALPL', 'GJA1', 'ACAD8', 'RGMB', 'FLVCR1', 'ANPEP', 'CD274', 'CXCL1', 'ANXA1', 'ANXA2', 'FOXA2', 'HSPA1B', 'HSP90AA1', 'APOE', 'IGFBP3', 'APP', 'IL6ST', 'TNFRSF9', 'IDO1', 'INSRR', 'IRF7', 'ARNTL', 'MIR192', 'MIR200A', 'MIR216A', 'MIR22', 'MEFV', 'ACHE', 'CD200', 'MUSK', 'MYC', 'NHS', 'TNFRSF11B', 'OSM', 'NOX4', 'TAS2R14', 'PCNA', 'TLR8', 'PDCD1', 'PECAM1', 'PLD1', 'PMCH', 'PNOC', 'PPARA', 'PRKCB', 'EAF2', 'PSMB6', 'PTPN6', 'PTPRE', 'RAPSN', 'ACE2', 'RBP4', 'RGS4', 'BCL6', 'ROS1', 'RPE65', 'CCL3', 'CXCL11', 'SELP', 'SEMA4A', 'CLEC7A', 'SLC6A4', 'GGTLC5P', 'SLC8A1', 'SNRNP70', 'TAC3', 'TEK', 'TFF2', 'TGFBR2', 'THBD', 'TM7SF2', 'TP53', 'TRPC3', 'GGTLC3', 'GGT2', 'TWIST1', 'GGTLC4P', 'TYRO3', 'XBP1', 'FTO', 'NR4A3', 'FLAD1', 'TAGLN2', 'NR0B2', 'IL1F10', 'SOCS1', 'TNFSF10', 'MSC', 'CD163', 'CLOCK', 'CD44', 'SEMA3E', 'HDAC4', 'ZGLP1', 'AAA1', 'DNM1L', 'CDH13', 'WASF2', 'CDKN1A', 'LOC102724197', 'YAP1', 'FST', 'CEACAM5', 'SEMA4D', 'SORBS1', 'KHDRBS1', 'CETN1', 'EBP', 'NES', 'CCR9', 'WASF3', 'PPARGC1A', 'SLC27A4', 'CHEK1', 'IL1RAPL1', 'AKAP13', 'CHRNA5', 'TXNRD3', 'CISH', 'CLN3', 'ADH1B', 'CNGB1', 'COL6A1', 'TMEM18', 'COL9A3', 'COMP', 'CORT', 'CPB2', 'CRH', 'HT', 'CSF1R', 'CST3', 'CSTA', 'PM20D1', 'CTSK', 'CYP1A1', 'CYP1B1', 'GRK2', 'CYP2E1', 'CYP3A4', 'CYP11A1', 'CYP27A1', 'DAG1', 'DGKG', 'DDIT3', 'DMD', 'ATN1', 'TSC22D3', 'AHSG', 'MLKL', 'EIF4E', 'ELAVL2', 'A2M', 'ELN', 'CRYBG1', 'AKT2', 'ESRRB', 'F10', 'F13A1', 'FABP4', 'THSD7A', 'FGF13', 'SIRT2', 'FAIM2', 'FLT1', 'DICER1', 'NUP62', 'LY96', 'NR5A1', 'FYN', 'G6PD', 'NEGR1', 'SPDEF', 'SH2B1', 'GAS6', 'GATA2', 'SLC17A5', 'AMH', 'GHRH', 'FOXP1', 'PDCD4', 'SGSM3', 'GLP1R', 'MAT2B', 'CAVIN1', 'GPR35', 'FFAR3', 'FFAR2', 'GRK5', 'GPX1', 'GPX3', 'GRN', 'PYCARD', 'TBK1', 'CXCL2', 'GRP', 'GSR', 'GTF2H1', 'HAS2', 'ANXA6', 'NR4A1', 'HOXD13', 'HES1', 'BIRC2', 'HSF1', 'BIRC3', 'HSPA1A', 'HSPA5', 'HSPB1', 'HSPD1', 'IGFBP1', 'IRF3', 'AR', 'ITGB2', 'MALAT1', 'THEMIS', 'LBP', 'LCT', 'LDLR', 'LGALS1', 'LIPA', 'LNPEP', 'LOX', 'LPA', 'LRP1', 'CYP4F3', 'MIR125A', 'MIR132', 'MIR140', 'MIR143', 'MIR149', 'MIR17', 'MIR19B1', 'MIR203A', 'MIR210', 'MIR223', 'MIR23A', 'MIR23B', 'MIR31', 'MIR34A', 'NBR1', 'ARRB2', 'STS', 'MBP', 'MC4R', 'MMP19', 'MTTP', 'ATF3', 'ATF4', 'ATM', 'NPPA', 'ATP2A2', 'ATP2A3', 'NTS', 'MIR378A', 'OGG1', 'OXTR', 'ATP5F1B', 'INSIG2', 'SLC45A2', 'DCTN4', 'TNFRSF12A', 'DACT1', 'SCLY', 'SIRT7', 'SIRT6', 'ENPP1', 'GHRL', 'ADA2', 'PGF', 'PGR', 'ABCB1', 'PIK3R1', 'PLA2G1B', 'SLC38A2', 'PON2', 'KRT20', 'UGT1A6', 'UGT1A1', 'UGT1A3', 'PPIA', 'MARCHF1', 'AVP', 'IMPACT', 'MEG3', 'MIR448', 'ADCY10', 'SELENOS', 'APOBR', 'MAPK9', 'MAP2K3', 'EIF2AK2', 'PRNP', 'CTNNBL1', 'CCL28', 'MIR20B', 'PTH', 'SLC24A3', 'MIR146B', 'PTX3', 'CXCL16', 'RARRES2', 'GER', 'REN', 'RFC2', 'RHO', 'BRD2', 'GAS5', 'ROBO1', 'MIR483', 'RYR2', 'S100A4', 'S100A12', 'S100B', 'SAA1', 'SAA2', 'SAT1', 'SCN10A', 'CCL7', 'CCL8', 'BID', 'CXCL5', 'BLK', 'SFRP4', 'SFRP5', 'HHIP', 'SHBG', 'ATPAF1', 'ST6GAL1', 'P2RY12', 'WNK1', 'SLC2A1', 'SLC22A2', 'BMPR2', 'SLPI', 'BNIP3', 'SOD3', 'SPARC', 'ST13', 'STAT5A', 'STC1', 'STK11', 'ADAM17', 'TADA2A', 'TAL1', 'BTF3P11', 'TAZ', 'TBL1X', 'HNF1A', 'MIR33B', 'TH', 'THBS2', 'TLR5', 'TNFRSF1A', 'TNNI3', 'TRPC1', 'TUFM', 'TYRP1', 'USF1', 'VLDLR', 'BEST1', 'WNT1', 'WNT7A', 'WNT10B', 'XDH', 'XRCC1', 'ZFP36', 'EHMT1', 'CALCR', 'DOCK5', 'WDR26', 'PNPLA3', 'ADAM12', 'SLC38A1', 'TAM', 'ITCH', 'PLA2G6', 'DGKE', 'CAV1', 'TNFSF14', 'NRP1', 'CCN4', 'SQSTM1', 'WASF1', 'CCNE1', 'CCT', 'SLC33A1', 'GGTLC1', 'AURKB', 'XPR1', 'MS4A1', 'KLF4', 'PPIG', 'GSTO1', 'CD33', 'LY86', 'CD36', 'SCARB2', 'TBPL1', 'KEAP1'])]
obesity_matched
# Out:
#       Disease    Gene  Gene_id UniProt  \
# 0     Obesity    MC4R     4160  P32245
# 1     Obesity   PPARG     5468  P37231
# 2     Obesity    POMC     5443  P01189
# 5     Obesity   SH2B1    25970  Q9NRF2
# 6     Obesity     LEP     3952  P41159
# ...       ...     ...      ...     ...
# 2790  Obesity  CXCL14     9547  O95715
# 2799  Obesity    CD48      962  P09326
# 2800  Obesity    CD69      969  Q07108
# 2804  Obesity  SEMA3E     9723  O15041
# 2819  Obesity   CDC42      998  P60953
#
#                                         Gene_Full_Name  \
# 0                              melanocortin 4 receptor
# 1     peroxisome proliferator activated receptor gamma
# 2                                  proopiomelanocortin
# 5                               SH2B adaptor protein 1
# 6                                               leptin
# ...                                                ...
# 2790                   C-X-C motif chemokine ligand 14
# ...

# %%
asthma_matched.to_csv(r'C:\Users\kdwq643\Downloads\asthma_matched.csv', index = False)

# %%
obesity_matched.to_csv(r'C:\Users\kdwq643\Downloads\obesity_matched.csv', index = False)

# %%
finngen_genes = df3['nearest_genes'].to_list()
output1 = []
for Gene in df1['Gene']:
    if Gene in finngen_genes:
        output1.append(Gene)

# %%
print(output1)
#asthma from Disgen and obesity-related asthma from FinnGen
# Out:
# ['TSLP', 'IL33', 'PDE4D', 'GATA3', 'IL1B', 'PLA2G4A', 'ICOS', 'IL7R', 'SLC22A5', 'LPP', 'IL18RAP', 'POSTN', 'ZNF618', 'PARD3B', 'ZFPM2', 'MLLT3', 'OVOL1', 'TENM3', 'BDNF', 'SLC16A7', 'ADAMTSL1', 'FCGR3A', 'JUN', 'HLA-DRA', 'HLX', 'CYLD', 'FTO', 'CDH13', 'TMEM219', 'DGKB', 'THSD7A', 'FGF13', 'PLA2R1', 'ADGRL3', 'DICER1', 'NEGR1', 'FOXP1', 'GNAO1', 'HTR4', 'KDR', 'MAP3K1', 'DCTN4', 'CA10', 'ROBO1', 'STK10', 'TBL1X', 'TGFBR3', 'XDH', 'FAM167A', 'ITCH', 'CD33']

# %%
finngen_genes2 = df3['nearest_genes'].to_list()
output2 = []
for Gene in df2['Gene']:
    if Gene in finngen_genes2:
        output2.append(Gene)

# %%
print(output2)
#obesity from Disgen and obesity-related asthma from FinnGen
# Out:
# ['FTO', 'NEGR1', 'IL1B', 'SLC16A7', 'GUCY2C', 'XDH', 'GIPR', 'PDE3A', 'BDNF', 'NRXN3', 'WWOX', 'FAT1', 'AMY1C', 'NCAM2', 'PCDH9', 'PDE4D', 'CLIP2', 'IL33', 'WNT5A', 'OPRM1', 'DCTN4', 'CDH13', 'POSTN', 'ZFPM2', 'GUCA2B', 'PSAT1', 'KCNK3', 'VWF', 'TSLP', 'FGF13', 'HHEX', 'ASCL1', 'PLA2G4A', 'TMPRSS15', 'IRX5', 'OLFM1', 'ADAMTS5', 'MACROD2', 'FCGR3A', 'THSD7A', 'GPD1L', 'DICER1', 'GFI1', 'FOXP1', 'NCAM1', 'NR4A2', 'NOX3', 'CNTN3', 'PID1', 'NUDT11', 'HIF1AN', 'PRKD1', 'ZNF608', 'SEMA6A', 'RBMS1', 'ROBO1', 'NBEAL1', 'SMARCA2', 'SPINK1', 'SRC', 'TBL1X', 'YWHAZ', 'ITCH', 'ADGRV1', 'STX16', 'TRIM24', 'CD33']

# %%
finngen_matched_asthma = df3.loc[df3['nearest_genes'].isin(['TSLP', 'IL33', 'PDE4D', 'GATA3', 'IL1B', 'PLA2G4A', 'ICOS', 'IL7R', 'SLC22A5', 'LPP', 'IL18RAP', 'POSTN', 'ZNF618', 'PARD3B', 'ZFPM2', 'MLLT3', 'OVOL1', 'TENM3', 'BDNF', 'SLC16A7', 'ADAMTSL1', 'FCGR3A', 'JUN', 'HLA-DRA', 'HLX', 'CYLD', 'FTO', 'CDH13', 'TMEM219', 'DGKB', 'THSD7A', 'FGF13', 'PLA2R1', 'ADGRL3', 'DICER1', 'NEGR1', 'FOXP1', 'GNAO1', 'HTR4', 'KDR', 'MAP3K1', 'DCTN4', 'CA10', 'ROBO1', 'STK10', 'TBL1X', 'TGFBR3', 'XDH', 'FAM167A', 'ITCH', 'CD33'])]
finngen_matched_asthma
# Out:
#      chrom        pos  ref         alt nearest_genes  \
# 0       16   53765595    G           A           FTO
# 1        6   32454571    C           T       HLA-DRA
# 4        7   12014171    T          TA        THSD7A
# 5        8  105123239    G           A         ZFPM2
# 8        5  132369766    C           G       SLC22A5
# 11       5  148476669    T           C          HTR4
# 12       2  203963407    G           A          ICOS
# 17      10    9011169    C           T         GATA3
# 22       5  111066174    T           C          TSLP
# 23      16   29937080    G           A       TMEM219
# 28       5  150750648    G           A         DCTN4
# 37       1  220859150    G           A           HLX
# 42       5   35883149    C           G          IL7R
# 51      13   37524954    G           A         POSTN
# 55      23  139321199    C           T         FGF13
# 59       1   58859105    C           T           JUN
# 61       2  102459966    C           T       IL18RAP
# ...

# %%
finngen_matched_obesity = df3.loc[df3['nearest_genes'].isin(['FTO', 'NEGR1', 'IL1B', 'SLC16A7', 'GUCY2C', 'XDH', 'GIPR', 'PDE3A', 'BDNF', 'NRXN3', 'WWOX', 'FAT1', 'AMY1C', 'NCAM2', 'PCDH9', 'PDE4D', 'CLIP2', 'IL33', 'WNT5A', 'OPRM1', 'DCTN4', 'CDH13', 'POSTN', 'ZFPM2', 'GUCA2B', 'PSAT1', 'KCNK3', 'VWF', 'TSLP', 'FGF13', 'HHEX', 'ASCL1', 'PLA2G4A', 'TMPRSS15', 'IRX5', 'OLFM1', 'ADAMTS5', 'MACROD2', 'FCGR3A', 'THSD7A', 'GPD1L', 'DICER1', 'GFI1', 'FOXP1', 'NCAM1', 'NR4A2', 'NOX3', 'CNTN3', 'PID1', 'NUDT11', 'HIF1AN', 'PRKD1', 'ZNF608', 'SEMA6A', 'RBMS1', 'ROBO1', 'NBEAL1', 'SMARCA2', 'SPINK1', 'SRC', 'TBL1X', 'YWHAZ', 'ITCH', 'ADGRV1', 'STX16', 'TRIM24', 'CD33'])]
finngen_matched_obesity
# Out:
#      chrom        pos ref alt nearest_genes      most_severe      info  \
# 0       16   53765595   G   A           FTO           intron  0.998334
# 4        7   12014171   T  TA        THSD7A       intergenic  0.984077
# 5        8  105123239   G   A         ZFPM2           intron  0.994644
# 19       1   42142291   A   G        GUCA2B  downstream gene  0.924875
# 22       5  111066174   T   C          TSLP    upstream gene  0.964127
# ..     ...        ...  ..  ..           ...              ...       ...
# 281     16   55089381   T   A          IRX5       intergenic  0.932064
# 283      1  105263742   T   C         AMY1C       intergenic  0.983244
# 285     10  100641711   G   A        HIF1AN       intergenic  0.996129
# 290     12   14719974   C   T        GUCY2C           intron  0.685375
# 292     11   27655414   T   A          BDNF      3 prime UTR  0.883952
#
#      fin_enrichment       maf  maf_cases  maf_controls      beta  \
# ...

# %%
finngen_matched_obesity.to_csv(r'C:\Users\kdwq643\Downloads\finngen_matched_obesity.csv', index = False)

# %%
finngen_matched_asthma.to_csv(r'C:\Users\kdwq643\Downloads\finngen_matched_asthma.csv', index = False)

# %%
finngendf = [finngen_matched_obesity, finngen_matched_asthma]
finngen_matches = pd.concat(finngendf)
finngen_matches
# Out:
#      chrom        pos ref alt nearest_genes      most_severe      info  \
# 0       16   53765595   G   A           FTO           intron  0.998334
# 4        7   12014171   T  TA        THSD7A       intergenic  0.984077
# 5        8  105123239   G   A         ZFPM2           intron  0.994644
# 19       1   42142291   A   G        GUCA2B  downstream gene  0.924875
# 22       5  111066174   T   C          TSLP    upstream gene  0.964127
# ..     ...        ...  ..  ..           ...              ...       ...
# 274     19   51234659   C   T          CD33           intron  0.990876
# 278     11   65786253   A   G         OVOL1    upstream gene  0.806744
# 286      2  205555493   C   T        PARD3B           intron  0.977255
# 292     11   27655414   T   A          BDNF      3 prime UTR  0.883952
# 296      9   18232038   C   T      ADAMTSL1           intron  0.985035
#
#      fin_enrichment       maf  maf_cases  maf_controls      beta  \
# ...

# %%
finngen_matches['nearest_genes'].value_counts()
# Out:
# ROBO1      4
# ADGRL3     3
# FTO        2
# PCDH9      2
# CA10       2
#           ..
# WNT5A      1
# SMARCA2    1
# VWF        1
# NCAM2      1
# GPD1L      1
# Name: nearest_genes, Length: 95, dtype: int64

# %%
finngen_matches1 = finngen_matches.drop_duplicates(subset=['nearest_genes'])

# %%
finngen_matches1['nearest_genes'].value_counts()
# Out:
# TRIM24    1
# JUN       1
# ICOS      1
# SPINK1    1
# RBMS1     1
#          ..
# OPRM1     1
# PDE4D     1
# TENM3     1
# STK10     1
# FTO       1
# Name: nearest_genes, Length: 95, dtype: int64

# %%
pd.set_option('display.max_rows', None)
finngen_matches1
# Out:
#      chrom        pos  ref         alt nearest_genes  \
# 0       16   53765595    G           A           FTO
# 4        7   12014171    T          TA        THSD7A
# 5        8  105123239    G           A         ZFPM2
# 19       1   42142291    A           G        GUCA2B
# 22       5  111066174    T           C          TSLP
# 26       5  124606866    A           G        ZNF608
# 27       9  135043505    C           T         OLFM1
# 28       5  150750648    G           A         DCTN4
# 31      23   51479606    C           T        NUDT11
# 36       7   74311129    G           A         CLIP2
# 46      12    5963741    A           G           VWF
# 51      13   37524954    G           A         POSTN
# 55      23  139321199    C           T         FGF13
# 74       4  186734691    C           T          FAT1
# 75       3   71153862    G           A         FOXP1
# 76       2  112823950    C           T          IL1B
# 88      21   21413787    G           T         NCAM2
# ...

# %%
finngen_matches1.to_csv(r'C:\Users\kdwq643\Downloads\finngen_matches1.csv')

# %%
#finngen (obesity-related asthma) matches from disgen database of asthma and database of obesity

# %%
disgendf = [asthma_matched, obesity_matched]
disgen_matches = pd.concat(disgendf)
disgen_matches
# Out:
#       Disease          Gene    Gene_id                      UniProt  \
# 1      Asthma           IL5       3567                       P05113
# 2      Asthma          IL13       3596                       P35225
# 3      Asthma         CCL11       6356                       P51671
# 4      Asthma         TGFB1       7040                       P01137
# 5      Asthma         ICAM1       3383                       P05362
# 6      Asthma           IL4       3565                       P05112
# 7      Asthma           IL6       3569                       P05231
# 8      Asthma          MMP9       4318                       P14780
# 9      Asthma          NOS2       4843                       P35228
# 10     Asthma          CCL2       6347                       P13500
# 11     Asthma          CCL5       6352                       P13501
# 13     Asthma         ADRB2        154                       P07550
# 14     Asthma         ALOX5        240                       P09917
# ...

# %%
disgen_matches1 = disgen_matches.drop_duplicates(subset = ['Gene'])

# %%
disgen_matches1
# Out:
#      Disease          Gene    Gene_id                      UniProt  \
# 1     Asthma           IL5       3567                       P05113
# 2     Asthma          IL13       3596                       P35225
# 3     Asthma         CCL11       6356                       P51671
# 4     Asthma         TGFB1       7040                       P01137
# 5     Asthma         ICAM1       3383                       P05362
# 6     Asthma           IL4       3565                       P05112
# 7     Asthma           IL6       3569                       P05231
# 8     Asthma          MMP9       4318                       P14780
# 9     Asthma          NOS2       4843                       P35228
# 10    Asthma          CCL2       6347                       P13500
# 11    Asthma          CCL5       6352                       P13501
# 13    Asthma         ADRB2        154                       P07550
# 14    Asthma         ALOX5        240                       P09917
# ...

# %%
fg1 = df3['nearest_genes'].to_list()
output3 = []
for Gene in disgen_matches['Gene']:
    if Gene in fg1:
        output3.append(Gene)

# %%
print(output3)
# Out:
# ['TSLP', 'IL33', 'PDE4D', 'IL1B', 'PLA2G4A', 'POSTN', 'ZFPM2', 'BDNF', 'SLC16A7', 'FCGR3A', 'FTO', 'CDH13', 'THSD7A', 'FGF13', 'DICER1', 'NEGR1', 'FOXP1', 'DCTN4', 'ROBO1', 'TBL1X', 'XDH', 'ITCH', 'CD33', 'FTO', 'NEGR1', 'IL1B', 'SLC16A7', 'XDH', 'BDNF', 'PDE4D', 'IL33', 'DCTN4', 'CDH13', 'POSTN', 'ZFPM2', 'TSLP', 'FGF13', 'PLA2G4A', 'FCGR3A', 'THSD7A', 'DICER1', 'FOXP1', 'ROBO1', 'TBL1X', 'ITCH', 'CD33']

# %%
disgen_matches1 = disgen_matches.loc[disgen_matches['Gene'].isin(['TSLP', 'IL33', 'PDE4D', 'IL1B', 'PLA2G4A', 'POSTN', 'ZFPM2', 'BDNF', 'SLC16A7', 'FCGR3A', 'FTO', 'CDH13', 'THSD7A', 'FGF13', 'DICER1', 'NEGR1', 'FOXP1', 'DCTN4', 'ROBO1', 'TBL1X', 'XDH', 'ITCH', 'CD33', 'FTO', 'NEGR1', 'IL1B', 'SLC16A7', 'XDH', 'BDNF', 'PDE4D', 'IL33', 'DCTN4', 'CDH13', 'POSTN', 'ZFPM2', 'TSLP', 'FGF13', 'PLA2G4A', 'FCGR3A', 'THSD7A', 'DICER1', 'FOXP1', 'ROBO1', 'TBL1X', 'ITCH', 'CD33'])]
disgen_matches1
# Out:
#       Disease     Gene  Gene_id UniProt  \
# 20     Asthma     TSLP    85480  Q969D9
# 21     Asthma     IL33    90865  O95760
# 27     Asthma    PDE4D     5144  Q08499
# 47     Asthma     IL1B     3553  P01584
# 113    Asthma  PLA2G4A     5321  P47712
# 273    Asthma    POSTN    10631  Q15063
# 372    Asthma    ZFPM2    23414  Q8WW38
# 554    Asthma     BDNF      627  P23560
# 643    Asthma  SLC16A7     9194  O60669
# 693    Asthma   FCGR3A     2214  P08637
# 1164   Asthma      FTO    79068  Q9C0B1
# 1220   Asthma    CDH13     1012  P55290
# 1417   Asthma   THSD7A   221981  Q9UPZ6
# 1419   Asthma    FGF13     2258  Q92913
# 1437   Asthma   DICER1    23405  Q9UPY3
# 1452   Asthma    NEGR1   257194  Q7Z3B1
# 1474   Asthma    FOXP1    27086  Q9H334
# 1703   Asthma    DCTN4    51164  Q9UJW0
# 1828   Asthma    ROBO1     6091  Q9Y6N7
# 1922   Asthma    TBL1X     6907  O60907
# 1965   Asthma      XDH     7498  P47989
# 2014   Asthma     ITCH    83737  Q96J02
# ...

# %%
#disgen database of (obesity and asthma matches) matched with finngen database

# %%
disgen_matches1.to_csv(r'C:\Users\kdwq643\Downloads\disgen_matches1.csv', index = False)
